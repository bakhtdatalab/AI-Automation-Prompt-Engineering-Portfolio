# %% [markdown]
# # 📖 Python Word Counter
#
# A simple Python application developed in Google Colab that analyzes text entered by the user and provides useful statistics.
#
# ## 📌 Project Overview
#
# This application counts:
#
# * Total words
# * Total characters
# * Total sentences
#
# The project helped me practice Python string manipulation and text-processing techniques.
#
# ## 🚀 Features
#
# * Count words
# * Count characters
# * Count sentences
# * Simple command-line interface
#
# ## 🛠️ Technologies Used
#
# * Python 3
# * Google Colab
#
# ## 📚 Concepts Practiced
#
# * String Methods
# * Loops
# * Functions
# * User Input
# * Text Processing
#
# ## ▶️ How to Run
#
# 1. Open the notebook in Google Colab.
# 2. Run all cells.
# 3. Enter a paragraph or sentence.
# 4. The application displays text statistics.
#
# ## 🎯 Learning Outcomes
#
# This project improved my understanding of:
#
# * String manipulation
# * Text analysis
# * Python functions
# * Basic data processing
#
# ## 🔮 Future Improvements
#
# * Count paragraphs
# * Calculate reading time
# * Identify the most frequently used words
# * Remove punctuation before analysis
# * Export results to a CSV file
#
# ## 👨‍💻 Author
#
# **Bakht Zamin**
#
# *Python & Artificial Intelligence*

# %%
# Word Counter
word = input("Enter a paragraph or sentence: ")
word_count = len(word.split())
print("Total words:", word_count)

# Character Counter
character_count = len(word)
print("Total characters:", character_count)

# Sentence Counter
sentence_count = word.count('.') + word.count('!') + word.count('?')
print("Total sentences:", sentence_count)
# Out:
# Enter a paragraph or sentence: I help Shopify/Amazon sellers figure out what’s selling with data, then write the posts/emails/blogs that sell more.
# Total words: 17
# Total characters: 116
# Total sentences: 1
