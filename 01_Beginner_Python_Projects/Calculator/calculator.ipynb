# %% [markdown]
# # **AI Automation -AI Engineer or Machine Learning Engineer**
#
# ## **Basic to Advance Portfolio Projects**

# %% [markdown]
# ## 1. Writing a Simple Calculator

# %% [markdown]
#  # 🧮 Python Calculator
#
# A simple command-line calculator built using Python in Google Colab. This project performs basic arithmetic operations and was developed to strengthen my understanding of Python programming fundamentals.
#
# ## 📌 Project Overview
#
# The calculator accepts two numbers from the user and performs one of the following operations:
#
# * Addition
# * Subtraction
# * Multiplication
# * Division
#
# This project demonstrates the use of variables, functions, conditional statements, and user input in Python.
#
# ## 🚀 Features
#
# * User-friendly command-line interface
# * Supports four basic arithmetic operations
# * Handles invalid operations
# * Prevents division by zero
#
# ## 🛠️ Technologies Used
#
# * Python 3
# * Google Colab
#
# ## 📚 Concepts Practiced
#
# * Variables
# * Data Types
# * User Input (`input()`)
# * Conditional Statements (`if`, `elif`, `else`)
# * Functions
# * Error Handling
#
# ## ▶️ How to Run
#
# 1. Open the notebook in Google Colab.
# 2. Run all cells.
# 3. Enter two numbers.
# 4. Choose an arithmetic operation.
# 5. View the calculated result.
#
# ## 🎯 Learning Outcomes
#
# Through this project, I learned how to:
#
# * Build a simple interactive Python application.
# * Use functions to organize code.
# * Validate user input.
# * Handle common programming errors.
#
# ## 🔮 Future Improvements
#
# * Add exponent and modulus operations.
# * Support multiple calculations without restarting.
# * Build a graphical user interface (GUI).
#
# ## 👨‍💻 Author
#
# **Bakht Zamin**
#
# *AI Data-Driven Content for E-commerce Stores| Python & Artificial Intelligence*

# %%
number1 = int(input("Insert a number: "))
number2 = int(input("Insert your 2nd number: "))
operator = input("Choose an operation to perform ('+', '-', '*', '/'): ")

if operator == '+':
  print(number1 + number2)
elif operator == '-':
  print(number1 - number2)
elif operator == '*':
  print(number1 * number2)
elif operator == '/':
  if number2 != 0:
    print(number1 / number2)
  else:
    print("Error: Division by zero is not allowed.")
else:
  print("Invalid operator. Please choose from '+', '-', '*', '/'.")
# Out:
# Insert a number: 2
# Insert your 2nd number: 7
# Choose an operation to perform ('+', '-', '*', '/'): /
# 0.2857142857142857
